# %%
import pandas as pd

# %%
#saving filepath to a variable for easier access
melbourne_filepath = '../input/melbourne-housing-snapshot/melb_data.csv'

#read the data and call the dataframe melbourne_data
melbourne_data = pd.read_csv(melbourne_filepath)

#printing the  summary with .describe
melbourne_data.describe()

# %%
melbourne_data.isnull().sum()
